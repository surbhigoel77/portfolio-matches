# %%
import sys
sys.path.append("/home/alvis/Programming/NLPTask/")
from src.relevant import read_hn_embeddings, read_portfolio_embeddings, find_top_matches_agg, find_top_matches

# %%
import ast
import json

import numpy as np
import pandas as pd
import requests
import tiktoken
from openai.embeddings_utils import get_embedding
from sklearn.metrics.pairwise import cosine_similarity

OPENAI_API_KEY = "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"
url = "https://api.openai.com/v1/embeddings"

# embedding model parameters
embedding_model = "text-embedding-ada-002"
embedding_encoding = "cl100k_base"  # this the encoding for text-embedding-ada-002
max_tokens = 8000  # the maximum for text-embedding-ada-002 is 8191

# %%
hn_df = read_hn_embeddings("../src/data/hn_embeddings.csv")
portfolio_df = read_portfolio_embeddings("../src/data/portfolio_embeddings.csv")

# %%
hn_df.head()
# Out:
#                                               header  \
# 0  Crisis at Christmas | Volunteer position | Fle...
# 1  Magdalena Ridge Observatory | $80,000-$85,000/...
# 2  Qdrant | REMOTE | Full-time | https://qdrant.t...
# 3  Platform.sh | REMOTE | Full-Time | https://pla...
# 4  Matanuska Telecom Association | Software Engin...
#
#                      location  european  \
# 0            ['London', 'UK']      True
# 1  ['Magdalena', 'NM', 'USA']     False
# 2                          []     False
# 3                          []     False
# 4                          []     False
#
#                                          description  \
# 0  Not a job job but I'm hoping to find volunteer...
# 1  The Magdalena Ridge Observatory Interferometer...
# 2  Qdrant is a leading open-source Vector Databas...
# 3  Platform.sh is a unified, secure, enterprise-g...
# 4  MTA is an Alaskan ISP serving the southwest ar...
#
#                                             combined  n_tokens  \
# ...

# %%
hn_df = hn_df[hn_df["european"] == True]

# %%
find_top_matches_agg(hn_df, portfolio_df, 5)
# Out:
# Top Matches Aggregate:
#
# ...
#
# Potential investment match: Fy!
# Similar to the following companies in the current portfolio:
#     - Company: Frontify
#       Country: Switzerland
#       Sector : SaaS / Marketing
#
#     - Company: Localyze
#       Country: Germany
#       Sector : SaaS / HR
#
#     - Company: Spacelift
#       Country: Poland
#       Sector : Infrastructure / Developer Tools
#
# ----------------------------------------------------------------
#
# Potential investment match: Tulip
# Similar to the following companies in the current portfolio:
#     - Company: Tines
#       Country: Ireland
#       Sector : SaaS / Security
#
#     - Company: Spacelift
#       Country: Poland
#       Sector : Infrastructure / Developer Tools
#
#     - Company: Frontify
#       Country: Switzerland
#       Sector : SaaS / Marketing
#
# ----------------------------------------------------------------
#
# Potential investment match: Datadog
# ...

# %%
find_top_matches(hn_df, portfolio_df, 5)
# Out:
# Top Matches:
#
# -------------------------------------------------------------
# Company from HN: Datadog
# Top Match from the portfolio:
#     Name   : Sqreen
#     Country: France
#     Sector : Infrastructure / Security
# Similarity Value: 0.8285
# -------------------------------------------------------------
# Company from HN: Fy!
# Top Match from the portfolio:
#     Name   : Frontify
#     Country: Switzerland
#     Sector : SaaS / Marketing
# Similarity Value: 0.8170
# -------------------------------------------------------------
# Company from HN: Kombo (YC S22)
# Top Match from the portfolio:
#     Name   : Localyze
#     Country: Germany
#     Sector : SaaS / HR
# Similarity Value: 0.8076
# -------------------------------------------------------------
# Company from HN: Scale AI
# Top Match from the portfolio:
#     Name   : Localyze
#     Country: Germany
#     Sector : SaaS / HR
# Similarity Value: 0.8034
# -------------------------------------------------------------
# ...
